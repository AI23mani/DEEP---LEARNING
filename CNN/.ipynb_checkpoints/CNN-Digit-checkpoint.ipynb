# %%
# Basic Libraries
import numpy as np
import pandas as pd

# Visualization libraries
import matplotlib.pyplot as plt
import pydot
import seaborn as sns

#Evaluation library
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.model_selection import GridSearchCV

# Deep Learning libraries
import tensorflow as tf
from tensorflow.keras import layers
import keras
from keras.models import Sequential
from keras.layers.core import Dense,Activation,Dropout
from keras.datasets import mnist
from keras.utils.np_utils import to_categorical
from keras.wrappers.scikit_learn import KerasClassifier

# %%
import tensorflow as tf
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()

# %%
x_train.shape
# Out:
# (60000, 28, 28)

# %%
x_test.shape
# Out:
# (10000, 28, 28)

# %%
x_train = x_train.reshape(x_train.shape[0], 28, 28, 1)
x_test = x_test.reshape(x_test.shape[0], 28, 28, 1)
input_shape = (28, 28, 1)

# %%
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')

# %%
x_train /= 255
x_test /= 255

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, Dropout, Flatten, MaxPooling2D
model = Sequential()
model.add(Conv2D(28, kernel_size=(3,3), input_shape=input_shape))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Flatten())
model.add(Dense(128, activation=tf.nn.relu))
model.add(Dropout(0.2))
model.add(Dense(10,activation=tf.nn.softmax))

# %%
#https://keras.io/api/optimizers/
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
history=model.fit(x_train, y_train, batch_size=100, epochs=10,validation_data=(x_test, y_test))
# Out:
# Epoch 1/10
# 600/600 [==============================] - 18s 29ms/step - loss: 0.0115 - accuracy: 0.9963 - val_loss: 0.0625 - val_accuracy: 0.9862
# Epoch 2/10
# 600/600 [==============================] - 18s 30ms/step - loss: 0.0081 - accuracy: 0.9972 - val_loss: 0.0763 - val_accuracy: 0.9851
# Epoch 3/10
# 600/600 [==============================] - 18s 30ms/step - loss: 0.0085 - accuracy: 0.9971 - val_loss: 0.0606 - val_accuracy: 0.9863
# Epoch 4/10
# 600/600 [==============================] - 18s 30ms/step - loss: 0.0062 - accuracy: 0.9980 - val_loss: 0.0604 - val_accuracy: 0.9872
# Epoch 5/10
# 600/600 [==============================] - 18s 30ms/step - loss: 0.0074 - accuracy: 0.9974 - val_loss: 0.0662 - val_accuracy: 0.9854
# Epoch 6/10
# 600/600 [==============================] - 18s 30ms/step - loss: 0.0068 - accuracy: 0.9980 - val_loss: 0.0661 - val_accuracy: 0.9852
# Epoch 7/10
# 600/600 [==============================] - 18s 30ms/step - loss: 0.0064 - accuracy: 0.9978 - val_loss: 0.0723 - val_accuracy: 0.9857
# Epoch 8/10
# 600/600 [==============================] - 18s 31ms/step - loss: 0.0060 - accuracy: 0.9979 - val_loss: 0.0674 - val_accuracy: 0.9864
# Epoch 9/10
# 600/600 [==============================] - 18s 31ms/step - loss: 0.0057 - accuracy: 0.9979 - val_loss: 0.0694 - val_accuracy: 0.9856
# Epoch 10/10
# 600/600 [==============================] - 18s 31ms/step - loss: 0.0057 - accuracy: 0.9980 - val_loss: 0.0706 - val_accuracy: 0.9856

# %%
test_loss,test_accuracy=model.evaluate(x_test, y_test)
# Out:
# 313/313 [==============================] - 2s 5ms/step - loss: 0.0706 - accuracy: 0.9856

# %%
print('digit MNIST Test accuracy:', round(test_accuracy,4))
# Out:
# digit MNIST Test accuracy: 0.9856

# %%
y_predict = model.predict(x_test)
y_predicts = np.argmax(y_predict, axis=1)
y_test_eval = y_test

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Now you can proceed with generating the confusion matrix
con_mat = confusion_matrix(y_test_eval, y_predicts)

# Plotting
plt.style.use('seaborn-deep')
plt.figure(figsize=(10, 10))
sns.heatmap(con_mat, annot=True, annot_kws={'size': 15}, linewidths=0.5, fmt="d", cmap="gray")
plt.title('True or False predicted digit MNIST\n', fontweight='bold', fontsize=15)
plt.show()

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test_eval,y_predicts))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99       980
#            1       0.99      0.99      0.99      1135
#            2       0.99      0.98      0.99      1032
#            3       0.98      0.99      0.98      1010
#            4       0.98      0.99      0.99       982
#            5       0.99      0.99      0.99       892
#            6       0.99      0.99      0.99       958
#            7       0.98      0.98      0.98      1028
#            8       0.98      0.97      0.98       974
#            9       0.99      0.97      0.98      1009
#
#     accuracy                           0.99     10000
#    macro avg       0.99      0.99      0.99     10000
# weighted avg       0.99      0.99      0.99     10000

# %%
# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='best')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='best')
plt.show()

# %%
import matplotlib.pyplot as plt
image_index = 6900
plt.imshow(x_test[image_index].reshape(28, 28),cmap='Greys')
predict = x_test[image_index].reshape(28,28)
pred = model.predict(x_test[image_index].reshape(1, 28, 28, 1))
print(pred.argmax())
# Out:
# 6
